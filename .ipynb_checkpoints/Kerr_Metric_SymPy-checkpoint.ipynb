# %%
import sympy
from sympy import symbols, diff
from sympy.matrices import Matrix
from IPython.display import display, Math
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from sympy.utilities.autowrap import ufuncify

# %%
# The coordinates of space-time
coords = [symbols("t"), symbols("r"), symbols("theta"), symbols("phi")]

# %%
# Defining important constants and expressions
G, M, J, c = 1, 0.5, 0.225, 1
a = J/(M*c)
rs = 2*G*M/(c**2)
delta = (coords[1]**2)-rs*coords[1]+(a**2)
sigma = (coords[1]**2) + (a**2)*(sympy.cos(coords[2])**2)

# Coordinates
theta0 = np.pi/2
phi0 = 0
t0 = 0
r0 = 8*M
eps = -1

# Parameters
L = 2.1*M
E = 0.97
delta0 = (r0**2)-(r0*rs)+(a**2)
sigma0 = (r0**2) + (a**2)*(np.cos(theta0)**2)

# %%
# Calculation of Initial Velocities
v_t0 = 1/delta0 * ((r0**2)+(a**2) + 2*M*(a**2)*r0 * (np.sin(theta0)**2)/sigma0)*E - 2*M*a*r0/sigma0 * L
v_p0 = 1/delta0 * (2 * M * a * r0/sigma0 * E + (1 - 2 * M * r0/sigma0)*L/(np.sin(theta0)**2))
v_th0 = 0
v_r0 = -1*np.sqrt((eps - (-(1 - rs * r0/sigma0) * (c**2) * v_t0**2 - 2*rs * r0 * a * (np.sin(theta0)**2)/sigma0 * c * v_t0 * v_p0
                          + sigma0 * v_th0**2 + ((r0**2) + (a**2) + rs * r0 * (a**2)/sigma0 * (np.sin(theta0)**2)) * (np.sin(theta0)**2) * v_p0 **2))*delta0/sigma0)

print((eps - (-(1 - rs * r0/sigma0) * (c**2) * v_t0**2 - 2*rs * r0 * a * (np.sin(theta0)**2)/sigma0 * c * v_t0 * v_p0
                          + sigma0 * v_th0**2 + ((r0**2) + (a**2) + rs * r0 * (a**2)/sigma0 * (np.sin(theta0)**2)) * (np.sin(theta0)**2) * v_p0 **2))*delta0/sigma0)
print(v_r0, v_t0, v_p0, v_th0)
# Out:
# -0.026596057126720925
# nan 1.1738669073960255 0.07347879532882608 0
# /tmp/ipykernel_2050/388391465.py:5: RuntimeWarning: invalid value encountered in sqrt
#   v_r0 = -1*np.sqrt((eps - (-(1 - rs * r0/sigma0) * (c**2) * v_t0**2 - 2*rs * r0 * a * (np.sin(theta0)**2)/sigma0 * c * v_t0 * v_p0

# %%
# Defining the Metric
kerr = Matrix(4, 4, [-(1 - rs * coords[1]/sigma) * (c**2), 0, 0, -rs * coords[1] * a * (sympy.sin(coords[2])**2)/sigma * c,
				0, sigma/delta, 0, 0,
				0, 0, sigma, 0,
				-rs * coords[1] * a * (sympy.sin(coords[2])**2)/sigma * c, 0, 0,
				((coords[1]**2) + (a**2) + rs * coords[1] * (a**2)/sigma * (sympy.sin(coords[2])**2)) * (sympy.sin(coords[2])**2)])
kerr_inv = kerr.inv()

# %%
# Calculating the Christoffel Symbols
k_christoffel = []
for i in range(4):
	list1 = []
	for j in range(4):
		list2 = []
		for k in range(4):
			christoffel = 0
			for alpha in range(4):
				christoffel += 1/2 * kerr_inv[i, alpha] * (diff(kerr[alpha, k], coords[j]) + diff(kerr[alpha, j], coords[k]) - diff(kerr[j, k], coords[alpha]))
			list2.append(christoffel)
		list1.append(list2)
	k_christoffel.append(list1)

# %%
# Evaluating the four DEs
velocities = [symbols("v_t"), symbols("v_r"), symbols("v_th"), symbols("v_p")]

de0 = 0
for alpha in range(4):
    for beta in range(4):
        de0 -= k_christoffel[0][alpha][beta] * velocities[alpha] * velocities[beta]

de1 = 0
for alpha in range(4):
    for beta in range(4):
        de1 -= k_christoffel[1][alpha][beta] * velocities[alpha] * velocities[beta]

de2 = 0
for alpha in range(4):
    for beta in range(4):
        de2 -= k_christoffel[2][alpha][beta] * velocities[alpha] * velocities[beta]

de3 = 0
for alpha in range(4):
    for beta in range(4):
        de3 -= k_christoffel[3][alpha][beta] * velocities[alpha] * velocities[beta]

display(Math(sympy.latex(de0)))
display(Math(sympy.latex(de1)))
display(Math(sympy.latex(de2)))
display(Math(sympy.latex(de3)))
# Out:
# $\displaystyle - 2 v_{p} v_{r} \left(\frac{0.5 \left(\frac{0.9 r^{2} \sin^{2}{\left(\theta \right)}}{\left(r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}\right)^{2}} - \frac{0.45 \sin^{2}{\left(\theta \right)}}{r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}}\right) \left(- 1.0 r^{8} + 1.0 r^{7} - 0.6075 r^{6} \cos^{2}{\left(\theta \right)} - 0.2025 r^{6} - 0.2025 r^{5} \sin^{2}{\left(\theta \right)} + 0.405 r^{5} \cos^{2}{\left(\theta \right)} + 0.2025 r^{5} + 0.2025 r^{4} \sin^{2}{\left(\theta \right)} - 0.12301875 r^{4} \cos^{4}{\left(\theta \right)} - 0.12301875 r^{4} \cos^{2}{\left(\theta \right)} - 0.0820125 r^{3} \sin^{2}{\left(\theta \right)} \cos^{2}{\left(\theta \right)} + 0.04100625 r^{3} \cos^{4}{\left(\theta \right)} + 0.0820125 r^{3} \cos^{2}{\left(\theta \right)} + 0.04100625 r^{2} \sin^{2}{\left(\theta \right)} \cos^{2}{\left(\theta \right)} - 0.008303765625 r^{2} \cos^{6}{\left(\theta \right)} - 0.024911296875 r^{2} \cos^{4}{\left(\theta \right)} - 0.008303765625 r \sin^{2}{\left(\theta \right)} \cos^{4}{\left(\theta \right)} + 0.008303765625 r \cos^{4}{\left(\theta \right)} - 0.0016815125390625 \cos^{6}{\left(\theta \right)}\right)}{1.0 r^{8} - 2.0 r^{7} + 0.6075 r^{6} \cos^{2}{\left(\theta \right)} + 1.2025 r^{6} + 0.2025 r^{5} \sin^{2}{\left(\theta \right)} - 0.81 r^{5} \cos^{2}{\left(\theta \right)} - 0.405 r^{5} - 0.2025 r^{4} \sin^{2}{\left(\theta \right)} + 0.12301875 r^{4} \cos^{4}{\left(\theta \right)} + 0.32551875 r^{4} \cos^{2}{\left(\theta \right)} + 0.2025 r^{4} + 0.0820125 r^{3} \sin^{2}{\left(\theta \right)} \cos^{2}{\left(\theta \right)} - 0.0820125 r^{3} \cos^{4}{\left(\theta \right)} - 0.164025 r^{3} \cos^{2}{\left(\theta \right)} - 0.04100625 r^{2} \sin^{2}{\left(\theta \right)} \cos^{2}{\left(\theta \right)} + 0.008303765625 r^{2} \cos^{6}{\left(\theta \right)} + 0.024911296875 r^{2} \cos^{4}{\left(\theta \right)} + 0.04100625 r^{2} \cos^{2}{\left(\theta \right)} + 0.008303765625 r \sin^{2}{\left(\theta \right)} \cos^{4}{\left(\theta \right)} - 0.01660753125 r \cos^{4}{\left(\theta \right)} + 0.0016815125390625 \cos^{6}{\left(\theta \right)}} + \frac{0.5 \left(- \frac{0.405 r^{2} \sin^{2}{\left(\theta \right)}}{\left(r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}\right)^{2}} + 2 r + \frac{0.2025 \sin^{2}{\left(\theta \right)}}{r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}}\right) \left(- 0.45 r^{9} + 0.45 r^{8} - 0.3645 r^{7} \cos^{2}{\left(\theta \right)} + 0.273375 r^{6} \cos^{2}{\left(\theta \right)} - 0.110716875 r^{5} \cos^{4}{\left(\theta \right)} + 0.0553584375 r^{4} \cos^{4}{\left(\theta \right)} - 0.014946778125 r^{3} \cos^{6}{\left(\theta \right)} + 0.00373669453125 r^{2} \cos^{6}{\left(\theta \right)} - 0.000756680642578125 r \cos^{8}{\left(\theta \right)}\right) \sin^{2}{\left(\theta \right)}}{1.0 r^{12} - 2.0 r^{11} + 1.0125 r^{10} \cos^{2}{\left(\theta \right)} + 1.2025 r^{10} + 0.2025 r^{9} \sin^{2}{\left(\theta \right)} - 1.62 r^{9} \cos^{2}{\left(\theta \right)} - 0.405 r^{9} - 0.2025 r^{8} \sin^{2}{\left(\theta \right)} + 0.4100625 r^{8} \cos^{4}{\left(\theta \right)} + 0.81253125 r^{8} \cos^{2}{\left(\theta \right)} + 0.2025 r^{8} + 0.164025 r^{7} \sin^{2}{\left(\theta \right)} \cos^{2}{\left(\theta \right)} - 0.492075 r^{7} \cos^{4}{\left(\theta \right)} - 0.32805 r^{7} \cos^{2}{\left(\theta \right)} - 0.12301875 r^{6} \sin^{2}{\left(\theta \right)} \cos^{2}{\left(\theta \right)} + 0.08303765625 r^{6} \cos^{6}{\left(\theta \right)} + 0.20605640625 r^{6} \cos^{4}{\left(\theta \right)} + 0.12301875 r^{6} \cos^{2}{\left(\theta \right)} + 0.04982259375 r^{5} \sin^{2}{\left(\theta \right)} \cos^{4}{\left(\theta \right)} - 0.066430125 r^{5} \cos^{6}{\left(\theta \right)} - 0.0996451875 r^{5} \cos^{4}{\left(\theta \right)} - 0.024911296875 r^{4} \sin^{2}{\left(\theta \right)} \cos^{4}{\left(\theta \right)} + 0.0084075626953125 r^{4} \cos^{8}{\left(\theta \right)} + 0.025118891015625 r^{4} \cos^{6}{\left(\theta \right)} + 0.024911296875 r^{4} \cos^{4}{\left(\theta \right)} + 0.00672 ...
# $\displaystyle \frac{1.0 r v_{th}^{2} \left(1.0 r^{2} - 1.0 r + 0.2025\right)}{1.0 r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}} + \frac{0.5 v_{p}^{2} \left(1.0 r^{2} - 1.0 r + 0.2025\right) \left(- \frac{0.405 r^{2} \sin^{2}{\left(\theta \right)}}{\left(r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}\right)^{2}} + 2 r + \frac{0.2025 \sin^{2}{\left(\theta \right)}}{r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}}\right) \sin^{2}{\left(\theta \right)}}{1.0 r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}} - \frac{1.0 v_{p} v_{t} \left(- \frac{0.9 r^{2} \sin^{2}{\left(\theta \right)}}{\left(r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}\right)^{2}} + \frac{0.45 \sin^{2}{\left(\theta \right)}}{r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}}\right) \left(1.0 r^{2} - 1.0 r + 0.2025\right)}{1.0 r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}} - \frac{0.5 v_{r}^{2} \left(\frac{2 r}{r^{2} - 1.0 r + 0.2025} + \frac{\left(1.0 - 2 r\right) \left(r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}\right)}{\left(r^{2} - 1.0 r + 0.2025\right)^{2}}\right) \left(1.0 r^{2} - 1.0 r + 0.2025\right)}{1.0 r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}} + \frac{0.405 v_{r} v_{th} \left(1.0 r^{2} - 1.0 r + 0.2025\right) \sin{\left(\theta \right)} \cos{\left(\theta \right)}}{\left(1.0 r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}\right) \left(r^{2} - 1.0 r + 0.2025\right)} - \frac{0.5 v_{t}^{2} \left(\frac{2.0 r^{2}}{\left(r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}\right)^{2}} - \frac{1.0}{r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}}\right) \left(1.0 r^{2} - 1.0 r + 0.2025\right)}{1.0 r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}}$
# $\displaystyle - \frac{2.0 r v_{r} v_{th}}{r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}} + \frac{0.2025 r v_{t}^{2} \sin{\left(\theta \right)} \cos{\left(\theta \right)}}{\left(r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}\right)^{3}} - \frac{0.5 v_{p}^{2} \left(- \left(\frac{0.405 r \sin{\left(\theta \right)} \cos{\left(\theta \right)}}{r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}} + \frac{0.0820125 r \sin^{3}{\left(\theta \right)} \cos{\left(\theta \right)}}{\left(r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}\right)^{2}}\right) \sin^{2}{\left(\theta \right)} - 2 \left(r^{2} + \frac{0.2025 r \sin^{2}{\left(\theta \right)}}{r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}} + 0.2025\right) \sin{\left(\theta \right)} \cos{\left(\theta \right)}\right)}{r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}} - \frac{1.0 v_{p} v_{t} \left(\frac{0.9 r \sin{\left(\theta \right)} \cos{\left(\theta \right)}}{r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}} + \frac{0.18225 r \sin^{3}{\left(\theta \right)} \cos{\left(\theta \right)}}{\left(r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}\right)^{2}}\right)}{r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}} - \frac{0.2025 v_{r}^{2} \sin{\left(\theta \right)} \cos{\left(\theta \right)}}{\left(r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}\right) \left(r^{2} - 1.0 r + 0.2025\right)} + \frac{0.2025 v_{th}^{2} \sin{\left(\theta \right)} \cos{\left(\theta \right)}}{r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}}$
# $\displaystyle - 2 v_{p} v_{r} \left(- \frac{0.225 r \left(\frac{0.9 r^{2} \sin^{2}{\left(\theta \right)}}{\left(r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}\right)^{2}} - \frac{0.45 \sin^{2}{\left(\theta \right)}}{r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}}\right)}{1.0 r^{4} - 1.0 r^{3} + 0.2025 r^{2} \cos^{2}{\left(\theta \right)} + 0.2025 r^{2} + 0.2025 r \sin^{2}{\left(\theta \right)} - 0.2025 r + 0.04100625 \cos^{2}{\left(\theta \right)}} + \frac{0.5 \left(1.0 r^{2} - 1.0 r + 0.2025 \cos^{2}{\left(\theta \right)}\right) \left(- \frac{0.405 r^{2} \sin^{2}{\left(\theta \right)}}{\left(r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}\right)^{2}} + 2 r + \frac{0.2025 \sin^{2}{\left(\theta \right)}}{r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}}\right) \sin^{2}{\left(\theta \right)}}{1.0 r^{4} \sin^{2}{\left(\theta \right)} - 1.0 r^{3} \sin^{2}{\left(\theta \right)} + 0.2025 r^{2} \sin^{2}{\left(\theta \right)} \cos^{2}{\left(\theta \right)} + 0.2025 r^{2} \sin^{2}{\left(\theta \right)} + 0.2025 r \sin^{4}{\left(\theta \right)} - 0.2025 r \sin^{2}{\left(\theta \right)} + 0.04100625 \sin^{2}{\left(\theta \right)} \cos^{2}{\left(\theta \right)}}\right) - 2 v_{p} v_{th} \left(- \frac{0.225 r \left(- \frac{0.9 r \sin{\left(\theta \right)} \cos{\left(\theta \right)}}{r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}} - \frac{0.18225 r \sin^{3}{\left(\theta \right)} \cos{\left(\theta \right)}}{\left(r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}\right)^{2}}\right)}{1.0 r^{4} - 1.0 r^{3} + 0.2025 r^{2} \cos^{2}{\left(\theta \right)} + 0.2025 r^{2} + 0.2025 r \sin^{2}{\left(\theta \right)} - 0.2025 r + 0.04100625 \cos^{2}{\left(\theta \right)}} + \frac{0.5 \left(\left(\frac{0.405 r \sin{\left(\theta \right)} \cos{\left(\theta \right)}}{r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}} + \frac{0.0820125 r \sin^{3}{\left(\theta \right)} \cos{\left(\theta \right)}}{\left(r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}\right)^{2}}\right) \sin^{2}{\left(\theta \right)} + 2 \left(r^{2} + \frac{0.2025 r \sin^{2}{\left(\theta \right)}}{r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}} + 0.2025\right) \sin{\left(\theta \right)} \cos{\left(\theta \right)}\right) \left(1.0 r^{2} - 1.0 r + 0.2025 \cos^{2}{\left(\theta \right)}\right)}{1.0 r^{4} \sin^{2}{\left(\theta \right)} - 1.0 r^{3} \sin^{2}{\left(\theta \right)} + 0.2025 r^{2} \sin^{2}{\left(\theta \right)} \cos^{2}{\left(\theta \right)} + 0.2025 r^{2} \sin^{2}{\left(\theta \right)} + 0.2025 r \sin^{4}{\left(\theta \right)} - 0.2025 r \sin^{2}{\left(\theta \right)} + 0.04100625 \sin^{2}{\left(\theta \right)} \cos^{2}{\left(\theta \right)}}\right) - 2 v_{r} v_{t} \left(- \frac{0.225 r \left(- \frac{2.0 r^{2}}{\left(r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}\right)^{2}} + \frac{1.0}{r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}}\right)}{1.0 r^{4} - 1.0 r^{3} + 0.2025 r^{2} \cos^{2}{\left(\theta \right)} + 0.2025 r^{2} + 0.2025 r \sin^{2}{\left(\theta \right)} - 0.2025 r + 0.04100625 \cos^{2}{\left(\theta \right)}} + \frac{0.5 \left(\frac{0.9 r^{2} \sin^{2}{\left(\theta \right)}}{\left(r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}\right)^{2}} - \frac{0.45 \sin^{2}{\left(\theta \right)}}{r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}}\right) \left(1.0 r^{2} - 1.0 r + 0.2025 \cos^{2}{\left(\theta \right)}\right)}{1.0 r^{4} \sin^{2}{\left(\theta \right)} - 1.0 r^{3} \sin^{2}{\left(\theta \right)} + 0.2025 r^{2} \sin^{2}{\left(\theta \right)} \cos^{2}{\left(\theta \right)} + 0.2025 r^{2} \sin^{2}{\left(\theta \right)} + 0.2025 r \sin^{4}{\left(\theta \right)} - 0.2025 r \sin^{2}{\left(\theta \right)} + 0.04100625 \sin^{2}{\left(\theta \right)} \cos^{2}{\left(\theta \right)}}\right) - 2 v_{t} v_{th} \left(- \frac{0.091125 r^{2} \sin{\left(\theta \right)} \cos{\left(\theta \right)}}{\left(r^{2} + 0.2025 \cos^{2}{\left(\theta \right)}\right)^{2} \left(1.0 r^{4} - 1.0 r^{3} + 0.2025 r^{2} \cos^{2}{\left(\theta \right)} + 0.2025 r^{2} + 0.2025 r \sin^{2}{\left(\theta \right)} - 0.2025 r + 0.04100625 \cos^{2}{\lef ...

# %%
# Solver function
f_de0 = ufuncify([coords[1], coords[2], velocities[0],
                            velocities[1], velocities[2], velocities[3]], de0)
f_de1 = ufuncify([coords[1], coords[2], velocities[0],
                            velocities[1], velocities[2], velocities[3]], de1)
f_de2 = ufuncify([coords[1], coords[2], velocities[0],
                            velocities[1], velocities[2], velocities[3]], de2)
f_de3 = ufuncify([coords[1], coords[2], velocities[0],
                            velocities[1], velocities[2], velocities[3]], de3)
def solve(l, r):
    t, r, theta, phi, v_t, v_r, v_th, v_p = r

    # DEs for positional coordinates
    f_t = v_t
    f_r = v_r
    f_th = v_th
    f_p = v_p

    # DEs for velocities

    f_v_t = f_de0(r, theta, v_t, v_r, v_th, v_p)
    f_v_r = f_de1(r, theta, v_t, v_r, v_th, v_p)
    f_v_th = f_de2(r, theta, v_t, v_r, v_th, v_p)
    f_v_p = f_de3(r, theta, v_t, v_r, v_th, v_p)

    # REMEMBER! Christoffel Symbols are symmetric and both their symmetric terms have to be added.

    return f_t, f_r, f_th, f_p, f_v_t, f_v_r, f_v_th, f_v_p

# %%
sol = solve_ivp(solve, (0,200), (t0, r0, theta0, phi0, v_t0, v_r0, v_th0, v_p0),
                t_eval=np.linspace(0,200,1000), rtol=1e-8, atol=1e-10, method='DOP853')

# %%
x = sol.y[1]*np.cos(sol.y[3])
y = sol.y[1]*np.sin(sol.y[3])

plt.scatter(x[0],y[0])
plt.scatter(0,0, label = "Singularity")
plt.plot(x,y, color ="black", label = "Path")

theta_c = np.linspace(0, 2*np.pi, 100)
x_c1 = (rs + np.sqrt(rs**2-4*a**2))/2 * np.cos(theta_c)
y_c1 = (rs + np.sqrt(rs**2-4*a**2))/2 * np.sin(theta_c)
plt.plot(x_c1, y_c1, color="red", label ="Outer Event Horizon")

x_c2 = (rs - np.sqrt(rs**2-4*a**2))/2 * np.cos(theta_c)
y_c2 = (rs - np.sqrt(rs**2-4*a**2))/2 * np.sin(theta_c)
plt.plot(x_c2, y_c2, color="red", label ="Inner Event Horizon")

plt.tight_layout()
plt.legend()
plt.grid()
plt.xlim((-5,5))
plt.ylim((-5,5))
plt.show()

# %%
sol
# Out:
#   message: Required step size is less than spacing between numbers.
#   success: False
#    status: -1
#         t: [ 0.000e+00  2.002e-01 ...  6.807e+00  7.007e+00]
#         y: [[ 0.000e+00  2.859e-01 ...  1.442e+01  1.724e+01]
#             [ 2.500e+00  2.480e+00 ...  8.278e-01  7.446e-01]
#             ...
#             [ 0.000e+00  2.923e-19 ...  2.160e-16  2.995e-16]
#             [ 1.803e-01  1.836e-01 ...  4.849e+00  1.783e+01]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 114176
#      njev: 0
#       nlu: 0
